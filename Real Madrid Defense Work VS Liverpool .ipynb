# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns

# %%
df = pd.read_csv("G:\\Extra\\My Works\\Data Science & Machine Learning\\Data Analysis and Visualization and Machine Learning\\Real Madrid(Defensive Work).csv")
df
# Out:
#      minute  second  teamId     x     y      period          type  \
# 0         0       9      52  20.8  22.7   FirstHalf  BallRecovery
# 1         0      50      52  23.6  70.0   FirstHalf  BallRecovery
# 2         0      52      52  28.1  75.8   FirstHalf          Foul
# 3         1      15      52  25.5  11.4   FirstHalf        TakeOn
# 4         1      16      52  24.9  13.7   FirstHalf     BallTouch
# ..      ...     ...     ...   ...   ...         ...           ...
# 211      92      39      52  16.4  15.0  SecondHalf  BallRecovery
# 212      92      49      52  38.9  18.6  SecondHalf          Foul
# 213      94      17      52  70.0  45.6  SecondHalf     Challenge
# 214      94      34      52   7.7  49.3  SecondHalf         Claim
# 215      95       0      52  63.5  38.1  SecondHalf          Foul
#
#           outcome  isTouch  playerId  endX  endY
# 0      Successful    False  106883.0   NaN   NaN
# 1      Successful    False   20874.0   NaN   NaN
# ...

# %%
# plot a StatsBomb pitch
#pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
#fig, ax = pitch.draw()

#this 

fig,ax = plt.subplots(figsize=(13.5,8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

pitch = Pitch(pitch_type='statsbomb',orientation='horizontal',
             pitch_color='#22312b',line_color="#c7d5cc",figsize=(16,11),
             constrained_layout=True,tight_layout=False)
pitch.draw(ax=ax)
plt.gca().invert_yaxis()

#create heatmap

#kde=sns.kdeplot(

    #df['y'],
    #shade=True,
    #shade_lowest= False,
    #n_levels = 15,
    #cut=4,
    #cmp ='flamingo_cmap'
#)
#plt.xlim(0,120)
#plt.ylim(0,80)
#plt.title('Real Madrid Against Liverpool UCL FINAL 2021/22',fontsize=24,color='white') 

#axs['endnote'].text(1, 0.5, '@Abu Rayhan', va='center', ha='right', fontsize=15,
                    #fontproperties=robotto_regular.prop, color='#dee6ea')

#plt.show()  
# If you are using a Jupyter notebook you do not need this line


for x in range(len(df['x'])):
    if df['outcome'][x] == 'Successful':
        plt.plot((df['x'][x],df['endX'][x]),(df['y'][x],df['endY'][x]),color='green')
        plt.scatter(df['x'][x],df['y'][x],color='green')
    if df['outcome'][x] == 'Unsuccessful':
        plt.plot((df['x'][x],df['endX'][x]),(df['y'][x],df['endY'][x]),color='red')
        plt.scatter(df['x'][x],df['y'][x],color='red')
    
plt.xlim(0,120)
plt.ylim(0,80)
plt.title('Real Madrid Defensive Work Against Liverpool UCL FINAL 2021/22',fontsize=15,color='white')
# Out:
# Text(0.5, 1.0, 'Real Madrid Defensive Work Against Liverpool UCL FINAL 2021/22')
